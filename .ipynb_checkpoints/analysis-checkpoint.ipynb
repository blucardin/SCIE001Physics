# %%
# Set up Python Facilities
import matplotlib.pyplot as plt
import numpy as np
import scipy
from scipy.optimize import curve_fit
from scipy import stats
from scipy.stats import poisson
from scipy.stats import norm
import math

# %matplotlib inline

# %% [markdown]
# ## Apparatus info:
# Apparatus number: 107 - (11)  \
# Iron source: Fe-55-(13)

# %% [markdown]
# # Introduction and Mesurment Strategy
# In the lab we will be measuring the count-rate of decay of a radiactive pice of iron at different distances using a giger counter. Then fitting it using a predicted model to determine how well the radiation data fits with our data.
#
# First we will measure the background ratiation by detecting using the giger coutner at a distance of 1.3 cm and detecting counts for 5 minutes with no source.
#
# Then, using a source, we will scan from our lowest distance to the source (1.3 cm) to our highest distance from our source (9.83 cm) and detect the rate of radiation detection.
#
# We chose to find the rate over 10s, as it allowed the counter to not overflow when it was right beside the source, but still allowed a lower uncertainty, as our uncertainty is equal to:
#
# $$\delta R = R \sqrt{\left(\frac{1}{N}\right) + \left(\frac{\delta t}{t}\right)^2}. \quad $$
#
# So a larger amount of time would lead to lower rate uncertainty.
#
# We also did not want to do a longer rate as that would need more time to collect the data.
#
# For the model, we wanted to use a model that accounted for the inverse square law as well as the attenuation.
#
# $$
# R(x) = \frac{a}{x^2}e^{-b x} + c
# $$
#
# We wanted to use this because of its physical significance, this accounts for both phenomenon that would affect the radiation coutn rate over just an exponential model, that does not account for the inverse sequared law affect of the radiation spreading out.

# %%
# Set up Python Facilities
import matplotlib.pyplot as plt
import numpy as np
import scipy
from scipy.optimize import curve_fit
from scipy import stats
from scipy.stats import poisson
from scipy.stats import norm
import math

# %matplotlib inline

# %% [markdown]
# ## Uncertainty calculations
#
# The count-rate, $R$, is the quantity that represents the rate at which the counts are being measured,
#
# $$R = N/t, \quad (1)$$
#
# where $t$ is the amount of time for which you counted and $N$ the number of counts observed.
#
# #### Uncertainty in $N$
#
# Radioactive decay is a random process, so as with the pendulum timing measurements, there will be variability when you run multiple trials. The randomness in this case is well-described by counting statistics (specifically by the Poisson distribution). These counting statistics tell us that the uncertainty in the number of counts N is given by:
#
# $$\delta N = \sqrt{N}.$$
#
# This means that if you make repeated measurements of $N$ over the same time interval $t$, but keep the other variables the same, that these measurements will follow a Poisson distribution and have a standard deviation of $\sqrt{N}$. For reference, for values of $N$ of approximately 10 or more, the poisson distribution behaves like a Gaussian distribution.
#
# #### Uncertainty in $R$
#
# We turn our attention to calculating the uncertainty in the count-rate $R$. We can write the relative uncertainty for $R$ as:
#
# $$\frac{\delta R}{R} = \sqrt{\left(\frac{\delta N}{N}\right)^2 + \left(\frac{\delta t}{t}\right)^2} $$
#
#
# $$\delta N = \sqrt{N}$$
# $$\frac{\delta R}{R} = \sqrt{\left(\frac{\sqrt{N}^2}{N^2}\right) + \left(\frac{\delta t}{t}\right)^2}. \quad $$
# $$\frac{\delta R}{R} = \sqrt{\left(\frac{N}{N^2}\right) + \left(\frac{\delta t}{t}\right)^2}. \quad $$
#
# $$\frac{\delta R}{R} = \sqrt{\left(\frac{1}{N}\right) + \left(\frac{\delta t}{t}\right)^2}. \quad $$
#
# We took repeated measurments of time using our phone and took the standard deviation to determine our delta t. So we can rewrire our equation to solve for delta R.
#
# $$\delta R = R \sqrt{\left(\frac{1}{N}\right) + \left(\frac{\delta t}{t}\right)^2}. \quad $$
#
# For uncertainty in distance, we used gaussian, with a range of 0.1 cm
#
# $$
# u[d] = 0.1/4 = 0.025 cm
# $$

# %% [markdown]
# # Initial Measurment
# For a background measument at 1.5 cm on the scale, we got a background of 61 counts in 5:00.27 minutes plugging this into the euqation gives a bacgkround of 0.2032 plus or minus 0.0260 counts per second.

# %%
#Identifying and reading the data
datafile = "Fe55.csv"

data = np.genfromtxt(datafile, delimiter=",", dtype=float)[2:]

distance = data[:, 0]
ddistance = (0.1/4)

y_var = data[:, 1]
y_uncertainty = np.full(len(y_var), 0.005/np.sqrt(3))

x_var = distance

# %%
for x, y in zip(x_var, y_var):
    print(x, ",", y)
# Out:
# 9.41 , 6.57
# 12.65 , 6.36
# 16.1 , 6.18
# 19.95 , 6.0
# 26.52 , 5.76
# 30.14 , 5.65
# 35.93 , 5.49
# 38.1 , 5.43
# 43.17 , 5.31
# 48.97 , 5.2
# 52.59 , 5.13
# 59.1 , 5.02
# 66.34 , 4.91
# 84.05 , 4.69
# 114.65 , 4.4
# 148.48 , 4.17
# 169.42 , 4.05
# 208.08 , 3.86
# 237.07 , 3.73
# 280.56 , 3.57
# 304.72 , 3.48
# 375.75 , 3.26

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Plotting:

# %% [markdown]
# In this case, we will simply use the columns of the .csv file, but in the future you can do some pre-processing calculations at this stage.
#
# Let's add the axis labels, plot title, and the lower and upper limits for the plot axes.

# %%
#Preparing the Plots
x_label = "Distance"
y_label = "Rate of Radiation Detection (counts/second)"
title = "Rate of Radiation Detection to Distance from Source"
xmax = max(x_var) * 1.05
xmin = 0 # min(x_var) - (xmax * 0.05)

ymin = min(y_var) * 0.95
ymax = max(y_var) * 1.05

# %% [markdown]
# Now lets make a graph of y_var vs. x_var, with error bars on the y data.

# %%
plt.errorbar(x_var, y_var, yerr=y_uncertainty, fmt="o", ms=5, color="blue", alpha=0.75)

plt.gcf().set_size_inches(15, 10)  # This sets the size of the plot
plt.grid(True)  # This toggles whether gridlines are displayed
plt.xlabel(x_label, fontsize=16)  # x-axis label
plt.ylabel(y_label, fontsize=16)  # y-axis label
plt.title(title, fontsize=25)  # Plot title

# To manually change the axis limits, uncomment (remove the # at the start) these lines:
#plt.ylim(ymin, ymax)  # This sets the range of the y-axis
#plt.xlim(xmin, xmax)  # This sets the range of the x-axis

# To save the plot as a .png, uncomment this:
#plt.savefig("plot", bbox_inches="tight", dpi=300)  # Saves the figure
# Out:
# Text(0.5, 1.0, 'Rate of Radiation Detection to Distance from Source')

# %% [markdown]
# ## Iterative Fitting:

# %% [markdown]
# This section fits the data with a specified model.
# You can choose any function to be your model; the currently set function is a linear function.
# The iterative fitting algorithm repeatedly guesses the fit parameters, using the method of gradient descent to improve on the previous guess until it converges to a satisfactory fit.

# %% [markdown]
# This block defines the mathematical function which will be used to fit the data. Here it is set to a linear function where the parameter $a$ is the slope and $b$ is the y-intercept. The values of the parameters are not set; the fitter will find the values for these parameters which best fit the data.

# %%
def FitFunction(x, a, b, c):
    y = a*np.exp(-b * x) + c
    return y

n_parameters = 3

# %% [markdown]
# Before we use this function to fit our data, we need to set up the fitting routine. We can optionally provide the following pieces of information to help out the fitter:
#
# - A list of lower and upper bounds for the parameters
# - A list of initial guesses for the parameters.
#
# Currently the parameter lower bounds and upper bounds (param_bounds) are set to -/+ infinity (np.inf), and the guesses (initial_param) are both set to 1. (You can set each bound and parameter manually; for example for three parameters: initial_guesses = (100, 5, 3).)

# %%
#Parameter Bounds ([lower bounds,...],[Upper bounds,...])
param_bounds=([-np.inf,-np.inf, -np.inf],[np.inf,np.inf, np.inf])  
initial_param=(1,1, 1)

# %% [markdown]
# Now we tell python to try to fit our function to the data, and also calculate errors on each parameter.

# %%
optimized_parameters, covariance_matrix = curve_fit(FitFunction, x_var,y_var,
                                                    sigma=y_uncertainty,absolute_sigma=True,
                                                    bounds=param_bounds,p0=initial_param)
parameter_errors = np.sqrt(np.diag(covariance_matrix))
# Out:
# /var/folders/m4/cdvshl897bl3n9bvrdnzc5tm0000gp/T/ipykernel_75382/1852336040.py:2: RuntimeWarning: overflow encountered in exp
#   y = a*np.exp(-b * x) + c

# %% [markdown]
# Finally we print out the best fit parameters and their errors.

# %%
for i in range(len(optimized_parameters)):
    print(f'Parameter #{i+1}: {optimized_parameters[i]:.6e} ± {parameter_errors[i]:.1e}')
# Out:
# Parameter #1: 3.237171e+00 ± 2.1e-03
# Parameter #2: 1.191900e-02 ± 2.4e-05
# Parameter #3: 3.468124e+00 ± 1.8e-03

# %% [markdown]
# ## Plotting the fit results:

# %% [markdown]
# To display the best fit function, we start by defining a range of x values for which to plot the function. We then create an array of 200 points within this x range. For each point, we use the best fit parameters from the previous section to calculate the y value of the function at that point.

# %%
# First calculate a reasonable range of x values for our line
x_length = max(x_var) - min(x_var)
x_min_l = 1.5 #in(x_var) - 0.05*x_length
x_max_l = max(x_var) + 0.05*x_length
# Create our array of 200 linearly-spaced points
xForLine = np.linspace(x_min_l,x_max_l,200)
# Calculate the y values of the best fit line
yForLine = FitFunction(xForLine,*optimized_parameters)

# %% [markdown]
# Now we are ready to plot the fit function with our data. We repeat the code to plot the previous graph, and then plot our fit function.

# %%
# Plot our data
plt.errorbar(x_var, y_var, yerr=y_uncertainty, fmt="o", ms=5, color="blue", alpha=0.75)

# Add grid lines, titles, and axis labels.
plt.gcf().set_size_inches(15, 10)  # This sets the size of the plot
plt.grid(True)  # This toggles whether gridlines are displayed
plt.xlabel(x_label, fontsize=16)  # x-axis label
plt.ylabel(y_label, fontsize=16)  # y-axis label
plt.title(title, fontsize=25)  # Plot title

# To manually change the axis limits, uncomment (remove the # at the start) these lines:
#plt.ylim(ymin, ymax)  # This sets the range of the y-axis
#plt.xlim(xmin, xmax)  # This sets the range of the x-axis

# Add the line to the plot
plt.plot(xForLine, yForLine, lw=3, color="red", alpha=0.5, label="Line of Best Fit")

# Add a legend
plt.legend()

# To save the plot as a .png, uncomment this:
#plt.savefig("plot_fit", bbox_inches="tight", dpi=300)  # Saves the figure

# %% [markdown]
# ## Diagnosing the goodness-of-fit:

# %% [markdown]
# Now lets calculate the residual for each data point, i.e. the difference between the data and the fit function.

# %%
residual = y_var - FitFunction(x_var,*optimized_parameters)

# %% [markdown]
# Lets plot the residuals graph. Recall that the residuals should be evenly distributed around zero, and there should be no visible trend or pattern in the residuals. Approximately 68% of the error bars should cross zero, and 95% of data points should be within two error bars of zero.

# %%
# Plot the residuals
plt.errorbar(x_var, residual, yerr=y_uncertainty, fmt="o", ms=5, color="black", alpha=0.75)

# Add grid lines, titles, and axis labels.
plt.gcf().set_size_inches(15, 10)  # This sets the size of the plot
plt.grid(True)  # This toggles whether gridlines are displayed
plt.xlabel(x_label, fontsize=16)  # x-axis label
plt.ylabel("Residuals", fontsize=16)  # y-axis label
plt.title(title, fontsize=25)  # Plot title

plt.axhline(0, color="black")


# Set the axis limits for the residuals plot
ymin_r= min(residual - y_uncertainty) * 1.05
ymax_r= max(residual + y_uncertainty) * 1.05
plt.ylim(ymin_r, ymax_r)  # This sets the range of the y-axis
plt.xlim(xmin, xmax)  # This sets the range of the x-axis

# To save the plot as a .png, uncomment this:
#plt.savefig("plot_residuals", bbox_inches="tight", dpi=300)  # Saves the figure
# Out:
# (0.0, 394.5375)

# %% [markdown]
# Lets also calculate the $\chi^2$ value for our fit. This indicates the goodness-of-fit:
# - $\chi^2>>1$ indicates the model is not a good fit to the data, or uncertainties are likely underestimated.
# - $\chi^2\sim1$ indicates the model is a good fit to the data.
# - $\chi^2<<1$ indicates the model is "too good" a fit, i.e. the uncertainties are likely overestimated.

# %%
ndof = len(x_var) - len(optimized_parameters) - 1 # Number of degrees of freedom ndof = no. entries - no. parameters -1
ru = residual / y_uncertainty
chisq = np.sum(np.power(ru, 2)) / ndof
print("Chisq", str.format("{0:.4f}", chisq))  # Print 4 significant figures
# Out:
# Chisq 1661.3313

# %% [markdown]
# # Conclusion

# %% [markdown]
# We found that the exponential model caused a chisq of 8.128, while taking into account the inverse-squared law cuased our chi-squared to spike to 84.23.
#
# Both with unbalanced residuals, specifically as the distance approched 0. This was moreso the vase for the inverse-square law model.
#
# This was similar to other groups at our table, getting chi-squareds from 1.5 to 8.
#
# Thinking about it, this is expected, because in our inverse squared model we assume that the radiation is coming from a point source wheareas, as we approch the source, it behaves more and more like a disk, and does not have the same assumptions as a point (the amount of radiation would increase faster than it was a point).
#
# Chopping some of the data near the 0 point, we get a better chi-squared of 1.634 with the attenuation equation, this further reinforces our idea that the change in radiation value is because of the size of the source.
#
# In summary, we achived our experimental goal of determining the distance-dependance of radiation detection from an iron source. We found that, it models an exponential decay relationship (accounting for the attenuation of air) along with an inverse-squared term to account for scattering over distance. This relationship only holds untill 2cm away from the source, then it is dominated by the size of our radiation source.
#
# To improve this experiment we could conduct it in a lead box with less background radiation, or just use a longer time to measure counts so that we can lower our uncertainty in our rate.
